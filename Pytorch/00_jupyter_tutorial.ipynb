# %% [markdown]
# # Jupyter Lab Tutorial

# %% [markdown]
# # Jupyter Lab 둘러보기
# - 디렉토리 조회
# - 파일 생성
# - 테마
# - 재실행

# %% [markdown]
# # Jupyter 의 기본 단위
#
# 스크립트와는 달리, 코드가 기본 콘텐츠인 경우에 다른 모든 것을 주석으로 적용해야 합니다. 하지만 노트북은 셀을 기반으로 합니다.
#
# 셀에는 다음과 같은 형식이 있을 수 있습니다:
#
# - 마크다운 형식의 텍스트 셀
# - 코드 셀 (파이썬 노트북에서는 파이썬 코드가 기본이지만, 다른 언어도 가능)
# - 원시, 형식이 지정되지 않은 텍스트

# %% [markdown]
# ### Code Cells
#
# 코드와 그 결과는 특별히 지정된 콘텐츠 블록에 표시
# <kbd>shift</kbd> + <kbd>return</kbd> 또는 <kbd>&#9654;</kbd> 버튼으로 실행

# %%
2 + 110
# Out:
# 112

# %%
a = 10
b = 20

# %%
z = a + b

# %%
z
# Out:
# 30

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ### Markdown Cells
# 마크다운을 지원하는 셀
#
# - *italics*
# - **bold**
# - `code`
# - [links](https://jupyterlab.readthedocs.io/)
# - Inline LaTeX equations: $E = mc^{2}$
#
#
# \begin{equation}
# e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i
# \end{equation}

# %% [markdown]
# ### Raw Cells
#
# Raw Text

# %% [raw]
# - *italics*
# - **bold**
# - `code`
# - [links](https://jupyterlab.readthedocs.io/)
# - Inline LaTeX equations: $E = mc^{2}$
#
# \begin{equation}
# e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i
# \end{equation}

# %% [markdown]
# ## shell 실행

# %%
# !mkdir tmp

# %%
# !ls
# Out:
# P03-CH01-01.jupyter_tutorial.ipynb    P03-Ch02-01.pandas_tutorial.ipynb
# P03-CH02-02.matplotlib_tutorial.ipynb tmp
# P03-CH02-03.numpy_tutorial.ipynb

# %%
# !pip install tqdm ipywidgets
# Out:
# Collecting tqdm
#   Using cached tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
# Collecting ipywidgets
#   Using cached ipywidgets-8.1.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in /opt/homebrew/Caskroom/miniconda/base/envs/fc-gemini/lib/python3.11/site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in /opt/homebrew/Caskroom/miniconda/base/envs/fc-gemini/lib/python3.11/site-packages (from ipywidgets) (8.20.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/homebrew/Caskroom/miniconda/base/envs/fc-gemini/lib/python3.11/site-packages (from ipywidgets) (5.14.1)
# Collecting widgetsnbextension~=4.0.9 (from ipywidgets)
#   Using cached widgetsnbextension-4.0.9-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.9 (from ipywidgets)
#   Using cached jupyterlab_widgets-3.0.9-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: decorator in /opt/homebrew/Caskroom/miniconda/base/envs/fc-gemini/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/homebrew/Caskroom/miniconda/base/envs/fc-gemini/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/homebrew/Caskroom/miniconda/base/envs/fc-gemini/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/homebrew/Caskroom/miniconda/base/envs/fc-gemini/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/homebrew/Caskroom/miniconda/base/envs/fc-gemini/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (2.17.2)
# Requirement already satisfied: stack-data in /opt/homebrew/Caskroom/miniconda/base/envs/fc-gemini/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /opt/homebrew/Caskroom/miniconda/base/envs/fc-gemini/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/homebrew/Caskroom/miniconda/base/envs/fc-gemini/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/homebrew/Caskroom/miniconda/base/envs/fc-gemini/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/homebrew/Caskroom/miniconda/base/envs/fc-gemini/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/fc-gemini/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/homebrew/Caskroom/miniconda/base/envs/fc-gemini/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/homebrew/Caskroom/miniconda/base/envs/fc-gemini/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/homebrew/Caskroom/miniconda/base/envs/fc-gemini/lib/python3.11/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# Using cached ipywidgets-8.1.1-py3-none-any.whl (139 kB)
# Using cached jupyterlab_widgets-3.0.9-py3-none-any.whl (214 kB)
# Using cached widgetsnbextension-4.0.9-py3-none-any.whl (2.3 MB)
# Installing collected packages: widgetsnbextension, tqdm, jupyterlab-widgets, ipywidgets
# Successfully installed ipywidgets-8.1.1 jupyterlab-widgets-3.0.9 tqdm-4.66.1 widgetsnbextension-4.0.9

# %%
from tqdm.notebook import tqdm

# %%
import time

for i in tqdm(range(20)):
    time.sleep(.5)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %% [markdown]
# ## Magic

# %%
# %%time
for i in tqdm(range(20)):
    time.sleep(.5)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# CPU times: user 34.9 ms, sys: 10.5 ms, total: 45.4 ms
# Wall time: 10.1 s

# %%
# %%timeit
sum(x**2 for x in range(1,100000,10))
# Out:
# 398 µs ± 1.81 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
